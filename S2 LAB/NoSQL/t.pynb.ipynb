# %%
import pymongo
conn=pymongo.MongoClient("mongodb://localhost:27017")
db=conn["test"]
col=db["demo"]

# %%
x=db.demo.insert_one({"Name":"Vidhya","Mark":{"Internal":48,"External":50}})
if x:
    print("inserted")
    #INSERTING VALUES TO MONGODB
# Out:
# inserted

# %%
x=db.demo.insert_many([{"_id":4,"Name":"D"}],[{"_id":5,"Name":"E"}])
if x:
    print("inserted")
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 x=db.demo.insert_many([{"_id":4,"Name":"D"}],[{"_id":5,"Name":"E"}])
#       2 if x:
#       3     print("inserted")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pymongo\_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pymongo\collection.py:755, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
# ...

# %%
x=db.demo.insert_one({"_id":3,"Name.fname.lname":"A,B"})
if x:
    print("inserted")
# Out:
# inserted

# %%
x=db.demo.insert_one({"_id":2,"Name":"B"})
if x:
    print("inserted")
# Out:
# inserted

# %%
x=db.demo.insert_one({"_id":1,"Name":"A"})
if x:
    print("inserted")
# Out:
# ---------------------------------------------------------------------------
# DuplicateKeyError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 x=db.demo.insert_one({"_id":1,"Name":"A"})
#       2 if x:
#       3     print("inserted")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pymongo\collection.py:669, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     665     document["_id"] = ObjectId()  # type: ignore[index]
#     667 write_concern = self._write_concern_for(session)
#     668 return InsertOneResult(
# --> 669     self._insert_one(
#     670         document,
#     671         ordered=True,
#     672         write_concern=write_concern,
#     673         op_id=None,
#     674         bypass_doc_val=bypass_document_validation,
#     675         session=session,
#     676         comment=comment,
# ...

# %%
x=db.demo.insert_one({"name":["fname,lname"],["A,B"]})
if x:
    print("inserted")
# Out:
# inserted

# %%
x=db.demo.insert_one({"name":"vidhya"})
if(x):
    print("inserted")
# Out:
# inserted
